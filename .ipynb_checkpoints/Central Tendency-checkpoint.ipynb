# %% [markdown]
# # Central Tendency (Mean & Median)
#
# Analysis perfomed to find the average(mean) and median(mid value) price of Airbnb by each neighbourhood group.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st

from pathlib import Path

# %%
filepath = Path("Resources/cleaned_airbnb_data.csv")
clean_df = pd.read_csv(filepath, low_memory=False)
clean_df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002755                                               NaN  85098326012
# 3  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 4  1005202                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 2            unconfirmed     Garry            Brooklyn        Clinton Hill
# 3               verified    Lyndon           Manhattan         East Harlem
# 4            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country  ... service fee  minimum nights  \
# 0  40.64749 -73.97237  United States  ...       193.0            10.0
# 1  40.75362 -73.98377  United States  ...        28.0            30.0
# 2  40.68514 -73.95976  United States  ...        74.0            30.0
# 3  40.79851 -73.94399  United States  ...        41.0            10.0
# 4  40.68688 -73.95596  United States  ...       212.0            45.0
#
#   number of reviews last review  reviews per month  review rate number  \
# 0               9.0  2021-10-19               0.21                 4.0
# 1              45.0  2022-05-21               0.38                 4.0
# 2             270.0  2019-07-05               4.64                 4.0
# 3               9.0  2018-11-19               0.10                 3.0
# 4              49.0  2017-10-05               0.40                 5.0
#
#    calculated host listings count  availability 365  \
# 0                             6.0             286.0
# 1                             2.0             228.0
# 2                             1.0             322.0
# 3                             1.0             289.0
# 4                             1.0             219.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2                                                NaN     NaN
# 3  Please no smoking in the house, porch or on th...     NaN
# 4  House Guidelines for our BnB We are delighted ...     NaN
#
# [5 rows x 26 columns]

# %%
clean_df['id'].nunique()
# Out:
# 82106

# %%
clean_df.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                     bool
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                               int64
# service fee                       float64
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# house_rules                        object
# license                            object
# dtype: object

# %%
clean_df['neighbourhood group'].value_counts()
# Out:
# neighbourhood group
# Brooklyn         34049
# Manhattan        33917
# Queens           11058
# Bronx             2267
# Staten Island      815
# Name: count, dtype: int64

# %%
clean_df['price_with_currency'] = '$' + clean_df['price'].astype(str)
clean_df['price_with_currency']
# Out:
# 0         $966
# 1         $142
# 2         $368
# 3         $204
# 4        $1060
#          ...
# 82101     $946
# 82102     $706
# 82103    $1043
# 82104     $809
# 82105    $1128
# Name: price_with_currency, Length: 82106, dtype: object

# %%
cleaned_df = clean_df.groupby(["neighbourhood group"])
cleaned_df.head()
# Out:
#           id                                               NAME      host id  \
# 0    1001254                 Clean & quiet apt home by the park  80014485718
# 1    1002102                              Skylit Midtown Castle  52335172823
# 2    1002755                                                NaN  85098326012
# 3    1003689   Entire Apt: Spacious Studio/Loft by central park  92037596077
# 4    1005202                                    BlissArtsSpace!  90821839709
# 5    1005754                    Large Furnished Room Near B'way  79384379533
# 6    1006859                 Cute & Cozy Lower East Side 1 bdrm   1280143094
# 7    1007411                   Beautiful 1br on Upper West Side  18824631834
# 9    1008516     Lovely Room 1, Garden, Best Area, Legal rental  26802410424
# 12   1022323                          Cute apt in artist's home  88653822946
# 41   1101855                 Beautiful Queens Brownstone! - 5BR  65716686884
# 54   1128365                  Nice, clean, safe, convenient 3BR  41153188173
# 76   1172549               Condo Apartment with laundry in unit  67156618342
# 83   1176415                One Bedroom Mini studio - Free WIFI  49542841946
# 95   1204582                   Oceanfront Apartment in Rockaway  81066007591
# 120  1241034  Artsy 1 bedroom Apt. 20 min to 42nd Grand Cent...  10971876811
# 122  1242139                          Astoria-Private Home NYC-  95697755445
# 176  1309519         Yankee Stadium Oasis 2 stops to Manhattan!  76341955125
# 186  1317252                 New Clean Spacious Bed & Breakfast  72246290898
# 197  1338791     Zen Yankee Stadium Pad 5 Minutes To Manhattan!  29241866652
# 222  1358122                  NY/ Big Room for 2 near Manhattan  25123739690
# 245  1390708                   Budget stay, near transportation  68286462615
# 350  1480180       Private Room in Artist's Home, Stapleton, SI  96774911627
# 417  1530439                    Enjoy Staten Island Hospitality  17079041199
# 766  1788364    Beautiful 4BR/4BA Home, Staten Island, NY City.  63542823809
#
#     host_identity_verified   host name neighbourhood group  \
# 0              unconfirmed    Madaline            Brooklyn
# 1                 verified       Jenna           Manhattan
# 2              unconfirmed       Garry            Brooklyn
# 3                 verified      Lyndon           Manhattan
# 4              unconfirmed        Emma            Brooklyn
# 5                 verified      Evelyn           Manhattan
# 6                 verified     Miranda           Manhattan
# 7                 verified        Alan           Manhattan
# 9                 verified       Darcy            Brooklyn
# 12                verified       Joyce            Brooklyn
# 41             unconfirmed        Brad              Queens
# 54             unconfirmed      Fowler              Queens
# 76                verified     Douglas               Bronx
# 83             unconfirmed     Hawkins              Queens
# 95                verified        Reed              Queens
# 120            unconfirmed       Darcy               Bronx
# 122            unconfirmed      Marcus              Queens
# 176               verified      Sydney               Bronx
# 186            unconfirmed         Max       Staten Island
# 197               verified   Frederick               Bronx
# 222            unconfirmed       Davis               Bronx
# 245            unconfirmed  Cunningham       Staten Island
# 350            unconfirmed     Russell       Staten Island
# 417            unconfirmed      Martin       Staten Island
# 766               verified      Marina       Staten Island
#
#           neighbourhood       lat      long        country  ...  \
# 0            Kensington  40.64749 -73.97237  United States  ...
# 1               Midtown  40.75362 -73.98377  United States  ...
# 2          Clinton Hill  40.68514 -73.95976  United States  ...
# 3           East Harlem  40.79851 -73.94399  United States  ...
# 4    Bedford-Stuyvesant  40.68688 -73.95596  United States  ...
# 5        Hell's Kitchen  40.76489 -73.98493  United States  ...
# 6             Chinatown  40.71344 -73.99037  United States  ...
# 7       Upper West Side  40.80316 -73.96545  United States  ...
# 9           South Slope  40.66829 -73.98779  United States  ...
# 12             Bushwick  40.70186 -73.92745  United States  ...
# 41            Ridgewood  40.70382 -73.89797  United States  ...
# 54            Ridgewood  40.70411 -73.89934  United States  ...
# 76          Kingsbridge  40.87207 -73.90193  United States  ...
# 83              Astoria  40.77635 -73.93426  United States  ...
# 95       Rockaway Beach  40.58615 -73.81245  United States  ...
# 120            Woodlawn  40.89747 -73.86390  United States  ...
# 122             Astoria  40.75725 -73.91098  United States  ...
# 176   Concourse Village  40.82802 -73.92039  United States  ...
# 186        Emerson Hill  40.60742 -74.14388  United States  ...
# 197           Concourse  40.83001 -73.92158  United States  ...
# 222         Kingsbridge  40.86790 -73.90023  United States  ...
# 245            Arrochar  40.59262 -74.06659  United States  ...
# 350             Clifton  40.62318 -74.07848  United States  ...
# 417        Graniteville  40.62109 -74.16534  United States  ...
# 766         Tottenville  40.50868 -74.23986  United States  ...
#
#     minimum nights  number of reviews last review reviews per month  \
# 0             10.0                9.0  2021-10-19              0.21
# 1             30.0               45.0  2022-05-21              0.38
# 2             30.0              270.0  2019-07-05              4.64
# 3             10.0                9.0  2018-11-19              0.10
# 4             45.0               49.0  2017-10-05              0.40
# 5              2.0              430.0  2019-06-24              3.47
# 6              1.0              160.0  2019-06-09              1.33
# 7              5.0               53.0  2019-06-22              0.43
# 9              4.0              167.0  2019-06-24              1.34
# 12             2.0              231.0  2019-06-22              1.96
# 41           166.0               10.0  2019-05-12              0.11
# 54            14.0                1.0  2022-04-03              0.01
# 76            30.0                4.0  2019-01-02              0.35
# 83             2.0              198.0  2019-05-31              2.01
# 95            27.0               13.0  2015-09-21              0.13
# 120            1.0              197.0  2019-06-23              2.49
# 122            1.0              414.0  2019-07-03              4.34
# 176            3.0              258.0  2019-06-25              2.70
# 186            2.0                2.0  2018-02-08              0.05
# 197            5.0              235.0  2019-06-29              2.49
# 222            2.0              108.0  2019-06-19              1.36
# 245            2.0                8.0  2019-05-19              0.09
# 350            1.0               50.0  2019-06-03              0.56
# 417            3.0               80.0  2019-05-26              0.92
# 766            3.0               59.0  2019-07-08              0.82
#
#      review rate number  calculated host listings count  availability 365  \
# 0                   4.0                             6.0             286.0
# 1                   4.0                             2.0             228.0
# 2                   4.0                             1.0             322.0
# 3                   3.0                             1.0             289.0
# 4                   5.0                             1.0             219.0
# 5                   3.0                             1.0             180.0
# 6                   3.0                             4.0               1.0
# 7                   4.0                             1.0             163.0
# 9                   4.0                             3.0              47.0
# 12                  3.0                             2.0             214.0
# 41                  4.0                             5.0             300.0
# 54                  5.0                             5.0              80.0
# 76                  5.0                             2.0             315.0
# 83                  1.0                             1.0              42.0
# 95                  3.0                             1.0             336.0
# 120                 5.0                             1.0             132.0
# 122                 5.0                             1.0             325.0
# 176                 1.0                             2.0             130.0
# 186                 1.0                             1.0              91.0
# 197                 2.0                             2.0              29.0
# 222                 1.0                             2.0               8.0
# 245                 1.0                             4.0             297.0
# 350                 3.0                             1.0             118.0
# 417                 1.0                             1.0             353.0
# 766                 2.0                             1.0             278.0
#
#                                            house_rules  license  \
# 0    Clean up and treat the home the way you'd like...      NaN
# 1    Pet friendly but please confirm with me if the...      NaN
# 2                                                  NaN      NaN
# 3    Please no smoking in the house, porch or on th...      NaN
# 4    House Guidelines for our BnB We are delighted ...      NaN
# 5    - Please clean up after yourself when using th...      NaN
# 6                                                  NaN      NaN
# 7    My ideal guests would be warm, friendly, and r...      NaN
# 9                                                  NaN      NaN
# 12   Please no shoes inside the house and no  smoki...      NaN
# 41                       No Parties allow  Non smoking      NaN
# 54   -Remove shoes -be sure to lock the front door ...      NaN
# 76   Our home is well cared for and loved. We would...      NaN
# 83   Please no smoking inside.  During the warmer m...      NaN
# 95   Dear Guest, Thank you for appreciating that I ...      NaN
# 120  No pets please - and no smoking in the apartme...      NaN
# 122  1. No parties. 2. Respect the neighbors. Noise...      NaN
# 176                                                NaN      NaN
# 186  Please remember that this is a residential bui...      NaN
# 197  Please remember that this is a residential bui...      NaN
# 222  PLEASE NOTE THE FOLLOWING BEFORE REQUESTING A ...      NaN
# 245  Please, no smoking, and treat our home like yo...      NaN
# 350  House Rules 1. Check-in is 4 pm local time. If...      NaN
# 417  This is a residential property. Quiet is impor...      NaN
# 766  Thank you for your reservation. By placing you...      NaN
#
#     price_with_currency
# 0                  $966
# 1                  $142
# 2                  $368
# 3                  $204
# 4                 $1060
# 5                 $1018
# 6                  $319
# 7                  $606
# 9                  $580
# 12                $1097
# 41                 $724
# 54                 $656
# 76                  $55
# 83                 $612
# 95                 $438
# 120                $811
# 122                $465
# 176                $581
# 186                $629
# 197                $361
# 222                $640
# 245                $845
# 350               $1174
# 417               $1178
# 766                $752
#
# [25 rows x 27 columns]

# %%
#Mean,Median,Min & Max for neighbourhood group by city
group_df = clean_df.groupby('neighbourhood group').agg({
    'price': ['mean','median','min','max'],
}).reset_index()
group_df.head()
# Out:
#   neighbourhood group       price
#                              mean median min   max
# 0               Bronx  630.534627  643.0  50  1200
# 1            Brooklyn  627.654762  627.0  50  1200
# 2           Manhattan  624.346316  624.0  50  1200
# 3              Queens  630.139808  630.0  50  1200
# 4       Staten Island  623.234356  625.0  50  1200

# %%
#Mean,Median for neighbourhood group by city
hood_df = clean_df.groupby('neighbourhood group').agg({
    'price': ['mean','median'],
}).reset_index()
hood_df.head()
# Out:
#   neighbourhood group       price
#                              mean median
# 0               Bronx  630.534627  643.0
# 1            Brooklyn  627.654762  627.0
# 2           Manhattan  624.346316  624.0
# 3              Queens  630.139808  630.0
# 4       Staten Island  623.234356  625.0

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
hood_df.plot(kind="bar", figsize=(20,3.5))

# Set a title for the chart
plt.title("Central Tendency")
plt.xlabel("neighbourhood group")
plt.ylabel("price")

plt.savefig("Resources/centraltendency.png")

plt.show()
plt.tight_layout()

# %%
#check the best measure of central tendency by determining if prices are normally distributed → use scipy.stats..normaltest
Bronx = clean_df.loc[clean_df["neighbourhood group"] == "Bronx", :]
print(Bronx)
# Out:
#              id                                               NAME  \
# 76      1172549               Condo Apartment with laundry in unit
# 120     1241034  Artsy 1 bedroom Apt. 20 min to 42nd Grand Cent...
# 176     1309519         Yankee Stadium Oasis 2 stops to Manhattan!
# 197     1338791     Zen Yankee Stadium Pad 5 Minutes To Manhattan!
# 222     1358122                  NY/ Big Room for 2 near Manhattan
# ...         ...                                                ...
# 81838  57186815   Superhost HUGE Room+Private Bath -Yankee Stadium
# 81919  57237074     Partitioned (shared) Cozy Studio in Pelham Bay
# 81978  57279049    Large Room with Private Bathroom (Long Term+++)
# 82000  57293961                      Clean and renovated apartment
# 82034  57315501       Comfy & Spacious RM with Backyard/Near Metro
#
#            host id host_identity_verified  host name neighbourhood group  \
# 76     67156618342               verified    Douglas               Bronx
# 120    10971876811            unconfirmed      Darcy               Bronx
# 176    76341955125               verified     Sydney               Bronx
# 197    29241866652               verified  Frederick               Bronx
# 222    25123739690            unconfirmed      Davis               Bronx
# ...            ...                    ...        ...                 ...
# 81838  23831329491            unconfirmed    Amílcar               Bronx
# 81919  59252893562            unconfirmed   Jonathan               Bronx
# 81978  47158281476               verified     Vernon               Bronx
# 82000    408825876            unconfirmed      Nance               Bronx
# 82034  90485544396            unconfirmed    Ciprian               Bronx
#
#            neighbourhood       lat      long        country  ...  \
# 76           Kingsbridge  40.87207 -73.90193  United States  ...
# 120             Woodlawn  40.89747 -73.86390  United States  ...
# 176    Concourse Village  40.82802 -73.92039  United States  ...
# 197            Concourse  40.83001 -73.92158  United States  ...
# 222          Kingsbridge  40.86790 -73.90023  United States  ...
# ...                  ...       ...       ...            ...  ...
# 81838         Highbridge  40.83173 -73.92824  United States  ...
# 81919      Schuylerville  40.84034 -73.83007  United States  ...
# 81978            Fordham  40.85929 -73.90048  United States  ...
# 82000           Longwood  40.81632 -73.90991  United States  ...
# 82034        Kingsbridge  40.87094 -73.89386  United States  ...
#
#       minimum nights  number of reviews last review reviews per month  \
# 76              30.0                4.0  2019-01-02              0.35
# 120              1.0              197.0  2019-06-23              2.49
# 176              3.0              258.0  2019-06-25              2.70
# 197              5.0              235.0  2019-06-29              2.49
# 222              2.0              108.0  2019-06-19              1.36
# ...              ...                ...         ...               ...
# 81838            1.0              127.0  2019-06-30              4.45
# 81919            1.0              116.0  2019-01-28              4.09
# 81978           22.0               10.0  2019-04-13              0.36
# 82000            2.0               62.0  2019-06-19              2.19
# 82034            3.0              115.0  2019-06-23              4.10
#
#        review rate number  calculated host listings count  availability 365  \
# 76                    5.0                             2.0             315.0
# 120                   5.0                             1.0             132.0
# 176                   1.0                             2.0             130.0
# 197                   2.0                             2.0              29.0
# 222                   1.0                             2.0               8.0
# ...                   ...                             ...               ...
# 81838                 1.0                             1.0             134.0
# 81919                 3.0                             1.0               5.0
# 81978                 3.0                             2.0             186.0
# 82000                 3.0                             1.0              36.0
# 82034                 3.0                             4.0              71.0
#
#                                              house_rules  license  \
# 76     Our home is well cared for and loved. We would...      NaN
# 120    No pets please - and no smoking in the apartme...      NaN
# 176                                                  NaN      NaN
# 197    Please remember that this is a residential bui...      NaN
# 222    PLEASE NOTE THE FOLLOWING BEFORE REQUESTING A ...      NaN
# ...                                                  ...      ...
# 81838  - Minimum two night stay  - No smoking or drug...      NaN
# 81919  Follow the Golden Rule of treating others (hom...      NaN
# 81978  Check-In is 3pm.  Check-Out is 12 Noon.  In or...      NaN
# 82000  -Remove shoes -be sure to lock the front door ...      NaN
# 82034  I feel very responsible and accountable for yo...      NaN
#
#       price_with_currency
# 76                    $55
# 120                  $811
# 176                  $581
# 197                  $361
# 222                  $640
# ...                   ...
# 81838               $1046
# 81919               $1011
# 81978                 $93
# 82000                $827
# 82034                $232
#
# [2267 rows x 27 columns]

# %%
print(st.normaltest(Bronx['price'].sample(50)))
# Out:
# NormaltestResult(statistic=5.135372146418975, pvalue=0.07671284812652084)

# %%
Brooklyn = clean_df.loc[clean_df["neighbourhood group"] == "Brooklyn", :]
print(Brooklyn)
# Out:
#              id                                             NAME      host id  \
# 0       1001254               Clean & quiet apt home by the park  80014485718
# 2       1002755                                              NaN  85098326012
# 4       1005202                                  BlissArtsSpace!  90821839709
# 9       1008516   Lovely Room 1, Garden, Best Area, Legal rental  26802410424
# 12      1022323                        Cute apt in artist's home  88653822946
# ...         ...                                              ...          ...
# 82093  57352505                     An East Williamsburg Delight  71564706996
# 82094  57353057                     Cozy bedroom in williamsburg  83101851929
# 82097  57355819          Private Room in Brooklyn Communal House  39435056937
# 82098  57356923                  HUGE BEDROOM LORIMER L TRAIN!!!  29320426760
# 82104  57360237  Lovely Two Bedroom & Event Space From Nonprofit  83006936257
#
#       host_identity_verified host name neighbourhood group  \
# 0                unconfirmed  Madaline            Brooklyn
# 2                unconfirmed     Garry            Brooklyn
# 4                unconfirmed      Emma            Brooklyn
# 9                   verified     Darcy            Brooklyn
# 12                  verified     Joyce            Brooklyn
# ...                      ...       ...                 ...
# 82093               verified     Petra            Brooklyn
# 82094               verified   Russell            Brooklyn
# 82097            unconfirmed      Emma            Brooklyn
# 82098            unconfirmed      Jose            Brooklyn
# 82104               verified       NaN            Brooklyn
#
#             neighbourhood       lat      long        country  ...  \
# 0              Kensington  40.64749 -73.97237  United States  ...
# 2            Clinton Hill  40.68514 -73.95976  United States  ...
# 4      Bedford-Stuyvesant  40.68688 -73.95596  United States  ...
# 9             South Slope  40.66829 -73.98779  United States  ...
# 12               Bushwick  40.70186 -73.92745  United States  ...
# ...                   ...       ...       ...            ...  ...
# 82093  Bedford-Stuyvesant  40.68335 -73.91222  United States  ...
# 82094        Williamsburg  40.70870 -73.96710  United States  ...
# 82097  Bedford-Stuyvesant  40.67964 -73.95629  United States  ...
# 82098        Williamsburg  40.71355 -73.95003  United States  ...
# 82104  Bedford-Stuyvesant  40.69095 -73.93444  United States  ...
#
#       minimum nights  number of reviews last review reviews per month  \
# 0               10.0                9.0  2021-10-19              0.21
# 2               30.0              270.0  2019-07-05              4.64
# 4               45.0               49.0  2017-10-05              0.40
# 9                4.0              167.0  2019-06-24              1.34
# 12               2.0              231.0  2019-06-22              1.96
# ...              ...                ...         ...               ...
# 82093            4.0               36.0  2018-06-27              1.28
# 82094            1.0               58.0  2019-06-10              2.08
# 82097            2.0               16.0  2017-10-21              0.57
# 82098           28.0               17.0  2019-04-30              0.61
# 82104           31.0                4.0  2019-05-29              0.16
#
#        review rate number  calculated host listings count  availability 365  \
# 0                     4.0                             6.0             286.0
# 2                     4.0                             1.0             322.0
# 4                     5.0                             1.0             219.0
# 9                     4.0                             3.0              47.0
# 12                    3.0                             2.0             214.0
# ...                   ...                             ...               ...
# 82093                 1.0                             1.0               0.0
# 82094                 5.0                             2.0             120.0
# 82097                 4.0                             3.0               0.0
# 82098                 1.0                             6.0             229.0
# 82104                 1.0                             1.0             178.0
#
#                                              house_rules  license  \
# 0      Clean up and treat the home the way you'd like...      NaN
# 2                                                    NaN      NaN
# 4      House Guidelines for our BnB We are delighted ...      NaN
# 9                                                    NaN      NaN
# 12     Please no shoes inside the house and no  smoki...      NaN
# ...                                                  ...      ...
# 82093                                                NaN      NaN
# 82094  - $150 Pet Fee - 14.45% Tax Will be adjusted i...      NaN
# 82097                                                NaN      NaN
# 82098                                         No smoking      NaN
# 82104                                                NaN      NaN
#
#       price_with_currency
# 0                    $966
# 2                    $368
# 4                   $1060
# 9                    $580
# 12                  $1097
# ...                   ...
# 82093                $455
# 82094               $1078
# 82097               $1073
# 82098                $570
# 82104                $809
#
# [34049 rows x 27 columns]

# %%
print(st.normaltest(Brooklyn['price'].sample(50)))
# Out:
# NormaltestResult(statistic=3.2002685475538466, pvalue=0.2018694104065965)

# %%
Manhattan = clean_df.loc[clean_df["neighbourhood group"] == "Manhattan", :]
print(Manhattan)
# Out:
#              id                                               NAME  \
# 1       1002102                              Skylit Midtown Castle
# 3       1003689   Entire Apt: Spacious Studio/Loft by central park
# 5       1005754                    Large Furnished Room Near B'way
# 6       1006859                 Cute & Cozy Lower East Side 1 bdrm
# 7       1007411                   Beautiful 1br on Upper West Side
# ...         ...                                                ...
# 82089  57349744       COZY Large Private APARTMENT in EAST VILLAGE
# 82099  57357476     Spacious two bedrooms condo in upper Manhattan
# 82102  57359133       Central Park Views - Private Room & Bathroom
# 82103  57359685  Ultimate 50th Floor Downtown Penthouse  - 4000...
# 82105  57367417                                    Rosalee Stewart
#
#            host id host_identity_verified host name neighbourhood group  \
# 1      52335172823               verified     Jenna           Manhattan
# 3      92037596077               verified    Lyndon           Manhattan
# 5      79384379533               verified    Evelyn           Manhattan
# 6       1280143094               verified   Miranda           Manhattan
# 7      18824631834               verified      Alan           Manhattan
# ...            ...                    ...       ...                 ...
# 82089  97186426683               verified      Luna           Manhattan
# 82099  14430571516               verified       Max           Manhattan
# 82102  68411243647               verified       NaN           Manhattan
# 82103  95625271612               verified       NaN           Manhattan
# 82105  93578954226               verified   Stanley           Manhattan
#
#          neighbourhood       lat      long        country  ... minimum nights  \
# 1              Midtown  40.75362 -73.98377  United States  ...           30.0
# 3          East Harlem  40.79851 -73.94399  United States  ...           10.0
# 5       Hell's Kitchen  40.76489 -73.98493  United States  ...            2.0
# 6            Chinatown  40.71344 -73.99037  United States  ...            1.0
# 7      Upper West Side  40.80316 -73.96545  United States  ...            5.0
# ...                ...       ...       ...            ...  ...            ...
# 82089     East Village  40.72588 -73.98598  United States  ...            6.0
# 82099           Inwood  40.86461 -73.92363  United States  ...            2.0
# 82102  Upper West Side  40.79712 -73.96117  United States  ...            1.0
# 82103             SoHo  40.72318 -74.00223  United States  ...            2.0
# 82105           Harlem  40.81315 -73.94747  United States  ...            4.0
#
#        number of reviews last review reviews per month  review rate number  \
# 1                   45.0  2022-05-21              0.38                 4.0
# 3                    9.0  2018-11-19              0.10                 3.0
# 5                  430.0  2019-06-24              3.47                 3.0
# 6                  160.0  2019-06-09              1.33                 3.0
# 7                   53.0  2019-06-22              0.43                 4.0
# ...                  ...         ...               ...                 ...
# 82089               22.0  2019-05-24              0.87                 2.0
# 82099               49.0  2019-05-23              1.81                 1.0
# 82102                4.0  2017-08-15              0.14                 4.0
# 82103               21.0  2019-07-01              0.74                 4.0
# 82105               22.0  2019-06-15              0.85                 4.0
#
#        calculated host listings count  availability 365  \
# 1                                 2.0             228.0
# 3                                 1.0             289.0
# 5                                 1.0             180.0
# 6                                 4.0               1.0
# 7                                 1.0             163.0
# ...                               ...               ...
# 82089                             1.0              15.0
# 82099                             3.0             147.0
# 82102                             1.0               0.0
# 82103                             2.0             343.0
# 82105                             1.0             238.0
#
#                                              house_rules  license  \
# 1      Pet friendly but please confirm with me if the...      NaN
# 3      Please no smoking in the house, porch or on th...      NaN
# 5      - Please clean up after yourself when using th...      NaN
# 6                                                    NaN      NaN
# 7      My ideal guests would be warm, friendly, and r...      NaN
# ...                                                  ...      ...
# 82089                                No Smoking, No Pets      NaN
# 82099                                                NaN      NaN
# 82102  My roommates and I take a lot of pride in keep...      NaN
# 82103                                             #NAME?      NaN
# 82105  Please remember that this is a residential bui...      NaN
#
#       price_with_currency
# 1                    $142
# 3                    $204
# 5                   $1018
# 6                    $319
# 7                    $606
# ...                   ...
# 82089                $878
# 82099                $665
# 82102                $706
# 82103               $1043
# 82105               $1128
#
# [33917 rows x 27 columns]

# %%
print(st.normaltest(Manhattan['price'].sample(50)))
# Out:
# NormaltestResult(statistic=11.632379780144682, pvalue=0.0029789336142569014)

# %%
Queens = clean_df.loc[clean_df["neighbourhood group"] == "Queens", :]
print(Queens)
# Out:
#              id                                              NAME  \
# 41      1101855                Beautiful Queens Brownstone! - 5BR
# 54      1128365                 Nice, clean, safe, convenient 3BR
# 83      1176415               One Bedroom Mini studio - Free WIFI
# 95      1204582                  Oceanfront Apartment in Rockaway
# 122     1242139                         Astoria-Private Home NYC-
# ...         ...                                               ...
# 82092  57351953            Cozy room in a 2B with backyard access
# 82095  57353610                            Spacious Room w/ 2 Bed
# 82096  57354162  Artsy Private Room in LIC. 2 min walk to Subway.
# 82100  57358028                     Room in Queens, NY, near LGA.
# 82101  57358580                          Cozy home away from home
#
#            host id host_identity_verified  host name neighbourhood group  \
# 41     65716686884            unconfirmed       Brad              Queens
# 54     41153188173            unconfirmed     Fowler              Queens
# 83     49542841946            unconfirmed    Hawkins              Queens
# 95     81066007591               verified       Reed              Queens
# 122    95697755445            unconfirmed     Marcus              Queens
# ...            ...                    ...        ...                 ...
# 82092   5155155913            unconfirmed   Cristina              Queens
# 82095  69037598918            unconfirmed  Christine              Queens
# 82096  18783843666            unconfirmed     Lunara              Queens
# 82100  56457739998               verified      Sonia              Queens
# 82101  60176837202               verified        NaN              Queens
#
#           neighbourhood       lat      long        country  ...  \
# 41            Ridgewood  40.70382 -73.89797  United States  ...
# 54            Ridgewood  40.70411 -73.89934  United States  ...
# 83              Astoria  40.77635 -73.93426  United States  ...
# 95       Rockaway Beach  40.58615 -73.81245  United States  ...
# 122             Astoria  40.75725 -73.91098  United States  ...
# ...                 ...       ...       ...            ...  ...
# 82092           Astoria  40.76987 -73.92679  United States  ...
# 82095           Bayside  40.75047 -73.75349  United States  ...
# 82096  Long Island City  40.74117 -73.94904  United States  ...
# 82100     East Elmhurst  40.76245 -73.87938  United States  ...
# 82101          Edgemere  40.59380 -73.77373  United States  ...
#
#       minimum nights  number of reviews last review reviews per month  \
# 41             166.0               10.0  2019-05-12              0.11
# 54              14.0                1.0  2022-04-03              0.01
# 83               2.0              198.0  2019-05-31              2.01
# 95              27.0               13.0  2015-09-21              0.13
# 122              1.0              414.0  2019-07-03              4.34
# ...              ...                ...         ...               ...
# 82092            1.0                9.0  2019-04-25              0.91
# 82095            7.0               40.0  2019-06-23              1.51
# 82096            5.0               17.0  2019-06-09              0.61
# 82100            1.0              239.0  2019-06-29              8.58
# 82101            1.0               76.0  2019-06-27              2.84
#
#        review rate number  calculated host listings count  availability 365  \
# 41                    4.0                             5.0             300.0
# 54                    5.0                             5.0              80.0
# 83                    1.0                             1.0              42.0
# 95                    3.0                             1.0             336.0
# 122                   5.0                             1.0             325.0
# ...                   ...                             ...               ...
# 82092                 3.0                             1.0               0.0
# 82095                 1.0                             5.0             148.0
# 82096                 1.0                             1.0             112.0
# 82100                 2.0                             2.0             361.0
# 82101                 1.0                             1.0             324.0
#
#                                              house_rules  license  \
# 41                         No Parties allow  Non smoking      NaN
# 54     -Remove shoes -be sure to lock the front door ...      NaN
# 83     Please no smoking inside.  During the warmer m...      NaN
# 95     Dear Guest, Thank you for appreciating that I ...      NaN
# 122    1. No parties. 2. Respect the neighbors. Noise...      NaN
# ...                                                  ...      ...
# 82092   I have other roommates so be respectful of that.      NaN
# 82095                                                NaN      NaN
# 82096                                                NaN      NaN
# 82100  1. Please clean-up after yourself in the kitch...      NaN
# 82101                                                NaN      NaN
#
#       price_with_currency
# 41                   $724
# 54                   $656
# 83                   $612
# 95                   $438
# 122                  $465
# ...                   ...
# 82092                $822
# 82095                $103
# 82096                $303
# 82100                $982
# 82101                $946
#
# [11058 rows x 27 columns]

# %%
print(st.normaltest(Queens['price'].sample(50)))
# Out:
# NormaltestResult(statistic=12.184868191168857, pvalue=0.0022599013986075427)

# %%
Staten_Island = clean_df.loc[clean_df["neighbourhood group"] == "Staten Island", :]
print(Staten_Island)
# Out:
#              id                                               NAME  \
# 186     1317252                 New Clean Spacious Bed & Breakfast
# 245     1390708                   Budget stay, near transportation
# 350     1480180       Private Room in Artist's Home, Stapleton, SI
# 417     1530439                    Enjoy Staten Island Hospitality
# 766     1788364    Beautiful 4BR/4BA Home, Staten Island, NY City.
# ...         ...                                                ...
# 81625  57049845   Lovely, private studio apartment near Manhattan.
# 81762  57137108  Contemporary. Spacious Apartment. Close to Ferry.
# 81855  57197309  @Ferry,HUGE 2Br/3beds. Private,Renovated/Styli...
# 81920  57237627                      Cherry Hill House - Blue Room
# 82011  57300037                              The Sweet Pea Cottage
#
#            host id host_identity_verified   host name neighbourhood group  \
# 186    72246290898            unconfirmed         Max       Staten Island
# 245    68286462615            unconfirmed  Cunningham       Staten Island
# 350    96774911627            unconfirmed     Russell       Staten Island
# 417    17079041199            unconfirmed      Martin       Staten Island
# 766    63542823809               verified      Marina       Staten Island
# ...            ...                    ...         ...                 ...
# 81625  79400670850               verified        John       Staten Island
# 81762  74590266826            unconfirmed        Paul       Staten Island
# 81855  74599588290            unconfirmed        Dine       Staten Island
# 81920  82856416783               verified     Jessica       Staten Island
# 82011  57639048216               verified    Kathleen       Staten Island
#
#       neighbourhood       lat      long        country  ... minimum nights  \
# 186    Emerson Hill  40.60742 -74.14388  United States  ...            2.0
# 245        Arrochar  40.59262 -74.06659  United States  ...            2.0
# 350         Clifton  40.62318 -74.07848  United States  ...            1.0
# 417    Graniteville  40.62109 -74.16534  United States  ...            3.0
# 766     Tottenville  40.50868 -74.23986  United States  ...            3.0
# ...             ...       ...       ...            ...  ...            ...
# 81625    St. George  40.64332 -74.08283  United States  ...            2.0
# 81762    St. George  40.64508 -74.08126  United States  ...            2.0
# 81855    St. George  40.64596 -74.08059  United States  ...            4.0
# 81920    St. George  40.63703 -74.08423  United States  ...            1.0
# 82011      Huguenot  40.53871 -74.16966  United States  ...            1.0
#
#        number of reviews last review reviews per month  review rate number  \
# 186                  2.0  2018-02-08              0.05                 1.0
# 245                  8.0  2019-05-19              0.09                 1.0
# 350                 50.0  2019-06-03              0.56                 3.0
# 417                 80.0  2019-05-26              0.92                 1.0
# 766                 59.0  2019-07-08              0.82                 2.0
# ...                  ...         ...               ...                 ...
# 81625              116.0  2019-07-05              4.00                 1.0
# 81762               59.0  2019-06-25              2.21                 2.0
# 81855               96.0  2019-07-01              3.42                 5.0
# 81920               12.0  2017-08-18              0.42                 1.0
# 82011              136.0  2019-07-07              4.81                 5.0
#
#        calculated host listings count  availability 365  \
# 186                               1.0              91.0
# 245                               4.0             297.0
# 350                               1.0             118.0
# 417                               1.0             353.0
# 766                               1.0             278.0
# ...                               ...               ...
# 81625                             1.0             191.0
# 81762                             1.0             135.0
# 81855                             6.0             147.0
# 81920                             2.0               0.0
# 82011                             1.0             136.0
#
#                                              house_rules  license  \
# 186    Please remember that this is a residential bui...      NaN
# 245    Please, no smoking, and treat our home like yo...      NaN
# 350    House Rules 1. Check-in is 4 pm local time. If...      NaN
# 417    This is a residential property. Quiet is impor...      NaN
# 766    Thank you for your reservation. By placing you...      NaN
# ...                                                  ...      ...
# 81625                                                NaN      NaN
# 81762  I expect them to come and go quietly and to le...      NaN
# 81855  Please tell me about who you will be traveling...      NaN
# 81920                                 - has to be clean!      NaN
# 82011  We expect that you will treat our house like y...      NaN
#
#       price_with_currency
# 186                  $629
# 245                  $845
# 350                 $1174
# 417                 $1178
# 766                  $752
# ...                   ...
# 81625                $998
# 81762               $1025
# 81855                $677
# 81920               $1008
# 82011                $968
#
# [815 rows x 27 columns]

# %%
print(st.normaltest(Staten_Island['price'].sample(50)))
# Out:
# NormaltestResult(statistic=4.283697203152768, pvalue=0.11743754700226304)

# %%
#st.normaltest for all neighbourhood group - QUESTION????
print(st.normaltest(clean_df['price'].sample(1000)))
# Out:
# NormaltestResult(statistic=739.5727916136321, pvalue=2.5340128811817035e-161)

# %%
#Count by price range (Groups ranging from min$50 - max$1200, $200 increments?: <200, 200-399, 400-599, 600-799, 800-999, 1000+) (Bar?)
#Repeat within each neighborhood group?
